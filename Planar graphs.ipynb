# %%
import numpy as np
import sympy as sp
import math
import Search_tools.analysis_lib as al
import pandas as pd
import csv
import networkx as nx

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
G = al.clear_H0(14,10,0.3)
print(nx.is_planar(G))
# Out:
# Memory during creation: 105.34 MB
# True

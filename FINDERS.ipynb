# %%
from networkx.algorithms import threshold

import Search_tools.analysis_lib as al
# %load_ext autoreload
# %autoreload 2

# %%
# %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import networkx as nx
import time

# %%
al.ExperimentEntry.initialize_id()
# Out:
# Initialized id to 131 from C:\Users\laure\PycharmProjects\Thesis\Logs\Required_odd_ext\31_03_2026_Computation_times.csv

# %%
n = 10
params = [5]
proba = [0.6]
def time_limit_fct(m):
    return 10

nb_trials = 15

# %%
al.plot_list(70)
# Out:
# [   Parameter  Probability
#  0         35     0.400000
#  1         35     0.411111
#  2         35     0.422222
#  3         35     0.433333
#  4         35     0.444444
#  5         35     0.455556
#  6         35     0.466667
#  7         35     0.477778
#  8         35     0.488889
#  9         35     0.500000]

# %%
al.print_graph_info(11)
# Out:
# Found ID 11 in file: C:\Users\laure\PycharmProjects\Thesis\Logs\Required_odd_ext\25_03_2026_Computation_times.csv
# {'id': 11, 'vertices': 40, 'parameter': 14, 'probability': 0.2, 'creation time': 1.0425810813903809, 'analysis time': 1000.124737739563, 'timestamp': '25_03_2026', 'exit via timeout': True, 'time limit': '1000s'}

# %%
from z3 import *

# %%
G = al.csv_to_graph_using_id('h')

# %%
al.print_graph_info(129)
# Out:
# Found ID 129 in file: C:\Users\laure\PycharmProjects\Thesis\Logs\Required_odd_ext\31_03_2026_Computation_times.csv
# {'id': 129, 'vertices': 50, 'parameter': 12, 'probability': 0.39, 'creation time': 2.0445, 'analysis time': 1100.6698, 'timestamp': '16:33:41', 'time limit': 'True', 'exit via timeout': '1100s'}

# %%
print(G)
nx.draw(G,with_labels=True)

# %%
set_param('sat.threads', 8)
set_param('parallel.enable', True)

# %%
al.further_analysis_with_SAT(G)
# Out:
# SAT found

# %%
al.move_file("sah.txt","Logs")
# Out:
# Moved: sah.txt -> Logs

# %%
al.increments(G,20)
# Out:
# --- Testing k = 20 ---
# Solver ready
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 al.increments(G,20)
#
# File ~\PycharmProjects\Thesis\Search_tools\analysis_lib\Candidate_analysis.py:120, in increments(graph, start_step)
#     116 # 2. Use set_param for global parallel settings if .set() fails
#     119 start = time.time()
# --> 120 result = s.check()
#     122 duration = round(time.time() - start, 4)
#     124 if result == sat:
#
# File ~\PycharmProjects\.venv\Lib\site-packages\z3\z3.py:7390, in Solver.check(self, *assumptions)
#    7386         num = len(assumptions)
#    7387         _assumptions = (Ast * num)()
#    7388         for i in range(num):
#    7389             _assumptions[i] = s.cast(assumptions[i]).as_ast()
# -> 7390         r = Z3_solver_check_assumptions(self.ctx.ref(), self.solver, num, _assumptions)
# ...

# %%
import Search_tools.analysis_lib as al
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import networkx as nx

# %%
al.ExperimentEntry.initialize_id()
# Out:
# Initialized id to 102 from C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Required_odd_ext\30_03_2026_Computation_times.csv

# %%
n = 30
param1,param2 = 5,5
proba = [0.6]
def time_limit_fct(m):
    return 10

nb_trials = 15

# %%
al.find_counterexamples(n,param1,param2,proba,time_limit_fct,nb_trials)
# Out:
# Initialized id to 102 from C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Required_odd_ext\30_03_2026_Computation_times.csv
# Time limit : 00:00:10
# Switched to 30 vertices, parameter 5 and with probability 0.6
# Trial:1
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Fast_computation\30_03_2026_OddExt_not_req_Computation_times.csv with id :None
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Fast_computation\30_03_2026_OddExt_not_req_Computation_times.csv with id :None
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Fast_computation\30_03_2026_OddExt_not_req_Computation_times.csv with id :None
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Fast_computation\30_03_2026_OddExt_not_req_Computation_times.csv with id :None
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Fast_computation\30_03_2026_OddExt_not_req_Computation_times.csv with id :None
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Fast_computation\30_03_2026_OddExt_not_req_Computation_times.csv with id :None
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Fast_computation\30_03_2026_OddExt_not_req_Computation_times.csv with id :None
# Odd extension required, creating odd extension, 17:27:33
# Odd extension : ok ! 17:27:33
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Required_odd_ext\30_03_2026_Computation_times.csv with id :102
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Fast_computation\30_03_2026_OddExt_not_req_Computation_times.csv with id :None
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Fast_computation\30_03_2026_OddExt_not_req_Computation_times.csv with id :None
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Fast_computation\30_03_2026_OddExt_not_req_Computation_times.csv with id :None
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Fast_computation\30_03_2026_OddExt_not_req_Computation_times.csv with id :None
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Fast_computation\30_03_2026_OddExt_not_req_Computation_times.csv with id :None
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Fast_computation\30_03_2026_OddExt_not_req_Computation_times.csv with id :None
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Fast_computation\30_03_2026_OddExt_not_req_Computation_times.csv with id :None

# %%
al.plot_list(70)
# Out:
# [   Parameter  Probability
#  0         35     0.400000
#  1         35     0.411111
#  2         35     0.422222
#  3         35     0.433333
#  4         35     0.444444
#  5         35     0.455556
#  6         35     0.466667
#  7         35     0.477778
#  8         35     0.488889
#  9         35     0.500000]

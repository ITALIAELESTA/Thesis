# %%
# %load_ext autoreload
# %autoreload 2
import Search_tools.analysis_lib as al
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %reload_ext autoreload

# %%
n = 50
proba = [0.4,0.5]
param1 = 20
param2=30
def time_limit_fct(y):
    return 10*y+600

nb_trials=1

# %%
print(f"{al.get_file_path('odd_directory')},\n"
      f"{al.get_file_path('non_odd_directory')},\n"
      f"{al.get_file_path('Garbage')}")
# Out:
# C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Required_odd_ext,
# C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Fast_computation,
# C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Garbage

# %%
al.find_counterexamples(n,param1=param1, param2=param2,proba_interval=proba,time_limit_fct=time_limit_fct,nb_trials=nb_trials)
# Out:
# Initialized id to 74 from C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Required_odd_ext/26_03_2026_Computation_times.csv
# C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Required_odd_ext/26_03_2026_Computation_times.csv
# Time limit : 00:18:20
# 0.4 0.5
# Switched to 50 vertices, parameter 20 and with probability 0.4
# Trial:1
# Odd extension required, creating odd extension, 15:39:14
# Odd extension : ok ! 15:39:18
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Required_odd_ext\26_03_2026_Computation_times.csv with id :74
# Switched to 50 vertices, parameter 21 and with probability 0.4
# Trial:1
# Odd extension required, creating odd extension, 15:39:37
# Odd extension : ok ! 15:39:40
# Timeout reached (1100s). Terminating search.
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Required_odd_ext\26_03_2026_Computation_times.csv with id :75
# time expired, possible candidate
# Saved: C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Candidates_w_ID\75.csv
# Switched to 50 vertices, parameter 22 and with probability 0.4
# Trial:1
# Odd extension required, creating odd extension, 15:58:01
# Odd extension : ok ! 15:58:04
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Required_odd_ext\26_03_2026_Computation_times.csv with id :76
# Switched to 50 vertices, parameter 23 and with probability 0.4
# Trial:1
# Odd extension required, creating odd extension, 15:58:29
# Odd extension : ok ! 15:58:32
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Required_odd_ext\26_03_2026_Computation_times.csv with id :77
# Switched to 50 vertices, parameter 24 and with probability 0.4
# Trial:1
# Odd extension required, creating odd extension, 15:58:48
# Odd extension : ok ! 15:58:51
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Required_odd_ext\26_03_2026_Computation_times.csv with id :78
# Switched to 50 vertices, parameter 25 and with probability 0.4
# Trial:1
# Odd extension required, creating odd extension, 15:59:08
# Odd extension : ok ! 15:59:11
# Timeout reached (1100s). Terminating search.
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Required_odd_ext\26_03_2026_Computation_times.csv with id :79
# time expired, possible candidate
# Saved: C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Candidates_w_ID\79.csv
# Switched to 50 vertices, parameter 26 and with probability 0.4
# Trial:1
# Odd extension required, creating odd extension, 16:17:32
# Odd extension : ok ! 16:17:34
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Required_odd_ext\26_03_2026_Computation_times.csv with id :80
# Switched to 50 vertices, parameter 27 and with probability 0.4
# Trial:1
# Odd extension required, creating odd extension, 16:17:52
# Odd extension : ok ! 16:17:57
# Timeout reached (1100s). Terminating search.
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Required_odd_ext\26_03_2026_Computation_times.csv with id :81
# time expired, possible candidate
# Saved: C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Candidates_w_ID\81.csv
# Switched to 50 vertices, parameter 28 and with probability 0.4
# Trial:1
# Odd extension required, creating odd extension, 16:36:18
# Odd extension : ok ! 16:36:20
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Required_odd_ext\26_03_2026_Computation_times.csv with id :82
# Switched to 50 vertices, parameter 29 and with probability 0.4
# Trial:1
# Odd extension required, creating odd extension, 16:36:55
# Odd extension : ok ! 16:36:58
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Required_odd_ext\26_03_2026_Computation_times.csv with id :83
# Switched to 50 vertices, parameter 30 and with probability 0.4
# Trial:1
# Odd extension required, creating odd extension, 16:41:10
# Odd extension : ok ! 16:41:13
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Required_odd_ext\26_03_2026_Computation_times.csv with id :84
# Switched to 50 vertices, parameter 20 and with probability 0.41000000000000003
# Trial:1
# Odd extension required, creating odd extension, 16:41:33
# Odd extension : ok ! 16:41:36
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Required_odd_ext\26_03_2026_Computation_times.csv with id :85
# Switched to 50 vertices, parameter 21 and with probability 0.41000000000000003
# Trial:1
# Odd extension required, creating odd extension, 16:41:58
# Odd extension : ok ! 16:42:01
# New data entry created in :C:\Users\Laurent Costa\PyCharmMiscProject\Thesis\Logs\Required_odd_ext\26_03_2026_Computation_times.csv with id :86
# Switched to 50 vertices, parameter 22 and with probability 0.41000000000000003
# Trial:1
# Odd extension required, creating odd extension, 16:42:23
# Odd extension : ok ! 16:42:25
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 al.find_counterexamples(n,param1=param1, param2=param2,proba_interval=proba,time_limit_fct=time_limit_fct,nb_trials=nb_trials)
#
# File ~\PyCharmMiscProject\Thesis\Search_tools\analysis_lib\Trial_functions.py:12, in find_counterexamples(nb_vertices, param1, param2, proba_interval, time_limit_fct, nb_trials)
#       6 from datetime import datetime
#       8 """
#       9 Add a function that takes a given graph, not just a random one (I already have it lol)
#      10 """
# ---> 12 def format_seconds(seconds):
#      13     """
#      14     Converts a float (seconds) into a string in HH:MM:SS format.
#      15     """
#      16     # Use divmod to get hours and the remaining seconds
#
# File ~\PyCharmMiscProject\Thesis\Search_tools\analysis_lib\Trial_functions.py:13, in run_trial(nb_vertices, param, proba, computation_time_limit, trial_number)
#      12 def format_seconds(seconds):
# ---> 13     """
#      14     Converts a float (seconds) into a string in HH:MM:SS format.
#      15     """
#      16     # Use divmod to get hours and the remaining seconds
#      17     hours, remainder = divmod(int(seconds), 3600)
#
# File ~\PyCharmMiscProject\Thesis\Search_tools\analysis_lib\Clique_search_fcts.py:104, in has_large_clique(graph, threshold, time_limit, nodes)
#     102             subg = subg_q
#     103             cand = cand_q
# --> 104             u = max(subg, key=lambda u: len(cand & adj[u]))
#     105             ext_u = cand - adj[u]
#     106 else:
#
# KeyboardInterrupt:
